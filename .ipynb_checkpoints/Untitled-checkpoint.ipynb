# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
import numpy as np
plt.style.use('fivethirtyeight')

from matplotlib import animation,rc
import io
import base64
from IPython.display import HTML, display
import warnings
warnings.filterwarnings('ignore')
from scipy.misc import imread
import codecs
from subprocess import check_output

# %%
df = pd.read_csv('data/data_csv.csv', nrows = 451, encoding = 'ISO-8859-1')

# %%
df.head()
# Out:
#            City      Lat      Long Total_Revenue Population  \
# 0      Adelanto  34.5868 -117.4411    14,565,863     33,497
# 1  Agoura Hills  34.1510 -118.7608    28,100,766     21,211
# 2       Alameda  37.7670 -122.2673   215,187,532     79,277
# 3        Albany  37.8898 -122.3018    35,120,955     18,893
# 4      Alhambra  34.0840 -118.1355   115,993,675     86,782
#
#   Revenue_per_capita Population_Fbi Violent_Crime  Murder Rape     ...       \
# 0                435         33,479           276       1   28     ...
# 1              1,325         21,032            15       0    2     ...
# 2              2,714         79,597           151       1    8     ...
# 3              1,859         19,975            29       0    0     ...
# 4              1,337         86,035           146       0    9     ...
#
#   Unnamed: 28 Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32 Unnamed: 33  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
df.isnull().sum()
# Out:
# City                     0
# Lat                      0
# Long                     0
# Total_Revenue            0
# Population               0
# Revenue_per_capita       0
# Population_Fbi           0
# Violent_Crime            0
# Murder                   0
# Rape                     0
# Robbery                  0
# Agg_Assault              0
# Property_Crime           0
# Burglary                 0
# Larceny_theft            0
# Motor_vehicle_theft      0
# Arson                    0
# Unnamed: 17            451
# Unnamed: 18            451
# Unnamed: 19            451
# Unnamed: 20            451
# Unnamed: 21            451
# Unnamed: 22            451
# Unnamed: 23            451
# Unnamed: 24            451
# Unnamed: 25            451
# Unnamed: 26            451
# Unnamed: 27            451
# Unnamed: 28            451
# Unnamed: 29            451
# Unnamed: 30            451
# Unnamed: 31            451
# Unnamed: 32            451
# Unnamed: 33            451
# ...

# %%
df = df[['City','Population','Total_Revenue','Revenue_per_capita','Population_Fbi','Violent_Crime','Murder','Rape','Robbery','Agg_Assault','Property_Crime','Burglary','Larceny_theft', 'Motor_vehicle_theft','Arson', 'Lat','Long']]

# %%
df.isnull().sum()
# Out:
# City                   0
# Population             0
# Total_Revenue          0
# Revenue_per_capita     0
# Population_Fbi         0
# Violent_Crime          0
# Murder                 0
# Rape                   0
# Robbery                0
# Agg_Assault            0
# Property_Crime         0
# Burglary               0
# Larceny_theft          0
# Motor_vehicle_theft    0
# Arson                  0
# Lat                    0
# Long                   0
# dtype: int64

# %%
df.loc[df['Violent_Crime'].idxmax()].City
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-97d406f8ad1f> in <module>()
# ----> 1 df.loc[df['Violent_Crime'].idxmax()].City
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\series.py in idxmax(self, axis, skipna, *args, **kwargs)
#    1781         """
#    1782         skipna = nv.validate_argmax_with_skipna(skipna, args, kwargs)
# -> 1783         i = nanops.nanargmax(com._values_from_object(self), skipna=skipna)
#    1784         if i == -1:
#    1785             return np.nan
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      72             if any(self.check(obj) for obj in obj_iter):
#      73                 msg = 'reduction operation {name!r} not allowed for this dtype'
# ...
