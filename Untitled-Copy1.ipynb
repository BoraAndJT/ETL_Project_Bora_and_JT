# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
import numpy as np
plt.style.use('fivethirtyeight')
import io
import base64
from IPython.display import HTML, display
import warnings
warnings.filterwarnings('ignore')
from scipy.misc import imread
import codecs
from subprocess import check_output

# %%
data = pd.read_csv('data/data_csv.csv', nrows = 451, encoding = 'ISO-8859-1')
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#            City      Lat      Long Total_Revenue Population  \
# 0      Adelanto  34.5868 -117.4411    14,565,863     33,497
# 1  Agoura Hills  34.1510 -118.7608    28,100,766     21,211
# 2       Alameda  37.7670 -122.2673   215,187,532     79,277
# 3        Albany  37.8898 -122.3018    35,120,955     18,893
# 4      Alhambra  34.0840 -118.1355   115,993,675     86,782
#
#   Revenue_per_capita Population_Fbi Violent_Crime  Murder Rape     ...       \
# 0                435         33,479           276       1   28     ...
# 1              1,325         21,032            15       0    2     ...
# 2              2,714         79,597           151       1    8     ...
# 3              1,859         19,975            29       0    0     ...
# 4              1,337         86,035           146       0    9     ...
#
#   Unnamed: 28 Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32 Unnamed: 33  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
df.isnull().sum()
# Out:
# City                     0
# Lat                      0
# Long                     0
# Total_Revenue            0
# Population               0
# Revenue_per_capita       0
# Population_Fbi           0
# Violent_Crime            0
# Murder                   0
# Rape                     0
# Robbery                  0
# Agg_Assault              0
# Property_Crime           0
# Burglary                 0
# Larceny_theft            0
# Motor_vehicle_theft      0
# Arson                    0
# Unnamed: 17            451
# Unnamed: 18            451
# Unnamed: 19            451
# Unnamed: 20            451
# Unnamed: 21            451
# Unnamed: 22            451
# Unnamed: 23            451
# Unnamed: 24            451
# Unnamed: 25            451
# Unnamed: 26            451
# Unnamed: 27            451
# Unnamed: 28            451
# Unnamed: 29            451
# Unnamed: 30            451
# Unnamed: 31            451
# Unnamed: 32            451
# Unnamed: 33            451
# ...

# %%
df = df[['City','Population','Total_Revenue','Revenue_per_capita','Population_Fbi','Violent_Crime','Murder','Rape','Robbery','Agg_Assault','Property_Crime','Burglary','Larceny_theft', 'Motor_vehicle_theft','Arson', 'Lat','Long']]

# %%
df_plot = df[['Violent_Crime','Murder','Rape','Robbery','Agg_Assault','Property_Crime','Burglary','Larceny_theft', 'Motor_vehicle_theft','Arson']]

# %%
df.isnull().sum()
# Out:
# City                   0
# Population             0
# Total_Revenue          0
# Revenue_per_capita     0
# Population_Fbi         0
# Violent_Crime          0
# Murder                 0
# Rape                   0
# Robbery                0
# Agg_Assault            0
# Property_Crime         0
# Burglary               0
# Larceny_theft          0
# Motor_vehicle_theft    0
# Arson                  0
# Lat                    0
# Long                   0
# dtype: int64

# %%
plt.subplots(figsize=(20,8))
sns.barplot(df['City'].value_counts()[:20].index, df['Violent_Crime'].value_counts()[:20].values, palette='inferno')
plt.title('Cities with the highest crime')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#columns = ['Violent_Crime','Murder','Rape','Robbery','Agg_Assault','Property_Crime','Burglary','Larceny_theft', 'Motor_vehicle_theft','Arson']
#df = df.reindex(columns=columns)
#df[columns] = df[columns].astype(float)

# %%
df.head(10)
# Out:
#               City Population  Total_Revenue Revenue_per_capita  \
# 0         Adelanto     33,497     14,565,863                435
# 1     Agoura Hills     21,211     28,100,766              1,325
# 2          Alameda     79,277    215,187,532              2,714
# 3           Albany     18,893     35,120,955              1,859
# 4         Alhambra     86,782    115,993,675              1,337
# 5      Aliso Viejo     50,509     20,608,025                408
# 6          Alturas      2,684      5,761,271              2,147
# 7  American Canyon     20,374     39,553,539              1,941
# 8          Anaheim    358,136  1,177,907,888              3,289
# 9         Anderson     10,485     13,138,675              1,253
#
#   Population_Fbi Violent_Crime  Murder Rape Robbery Agg_Assault  \
# 0         33,479           276       1   28      48         199
# 1         21,032            15       0    2       3          10
# 2         79,597           151       1    8      68          74
# ...

# %%
sortedlist = sorted(df, key=lambda column: column[5], reverse=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-7b6fb9d6e29b> in <module>()
# ----> 1 sortedlist = sorted(df, key=lambda column: column[5], reverse=True)
#
# <ipython-input-9-7b6fb9d6e29b> in <lambda>(column)
# ----> 1 sortedlist = sorted(df, key=lambda column: column[5], reverse=True)
#
# IndexError: string index out of range

# %%
df['Violent_Crime'].value_counts().plot(kind='pie', autopct='%1.1f%%', 
 startangle=90, shadow=False, labels=df['City'], legend = False, fontsize=14)

# %%
df[['Violent_Crime']] = df[['Violent_Crime']].apply(pd.to_numeric)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/src\inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "1,209"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-c346d8217d85> in <module>()
# ----> 1 df[['Violent_Crime']] = df[['Violent_Crime']].apply(pd.to_numeric)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6002                          args=args,
#    6003                          kwds=kwds)
# -> 6004         return op.get_result()
#    6005
#    6006     def applymap(self, func):
#
# ...
